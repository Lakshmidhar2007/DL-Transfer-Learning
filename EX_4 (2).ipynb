# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import models, datasets
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# %%
## Step 1: Load and Preprocess Data
# Define transformations for images
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize images for pre-trained model input
    transforms.ToTensor(),
    #transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Standard normalization for pre-trained models
])

# %%
# !unzip -qq ./chip_data.zip -d data

# %%
# Load dataset from a folder (structured as: dataset/class_name/images)
dataset_path = "./data/dataset/"
train_dataset = datasets.ImageFolder(root=f"{dataset_path}/train", transform=transform)
test_dataset = datasets.ImageFolder(root=f"{dataset_path}/test", transform=transform)

# %%
# Display some input images
def show_sample_images(dataset, num_images=5):
    fig, axes = plt.subplots(1, num_images, figsize=(5, 5))
    for i in range(num_images):
        image, label = dataset[i]
        image = image.permute(1, 2, 0)  # Convert tensor format (C, H, W) to (H, W, C)
        axes[i].imshow(image)
        axes[i].set_title(dataset.classes[label])
        axes[i].axis("off")
    plt.show()

# %%
# Show sample images from the training dataset
show_sample_images(train_dataset)

# %%
# Get the total number of samples in the training dataset
print(f"Total number of training samples: {len(train_dataset)}")

# Get the shape of the first image in the dataset
first_image, label = train_dataset[0]
print(f"Shape of the first image: {first_image.shape}")
# Out:
# Total number of training samples: 172
# Shape of the first image: torch.Size([3, 224, 224])

# %%
# Get the total number of samples in the testing dataset
print(f"Total number of test samples: {len(test_dataset)}")

# Get the shape of the first image in the dataset
first_image1, label = test_dataset[0]
print(f"Shape of the first image: {first_image1.shape}")
# Out:
# Total number of test samples: 121
# Shape of the first image: torch.Size([3, 224, 224])

# %%
# Create DataLoader for batch processing
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
## Step 2: Load Pretrained Model and Modify for Transfer Learning
# Load a pre-trained VGG19 model
# write your code here
model = models.vgg19(weights=models.VGG19_Weights.DEFAULT)

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
from torchsummary import summary
# Print model summary
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 4096]     102,764,544
#              ReLU-40                 [-1, 4096]               0
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 4096]      16,781,312
#              ReLU-43                 [-1, 4096]               0
#           Dropout-44                 [-1, 4096]               0
#            Linear-45                 [-1, 1000]       4,097,000
# ================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.69
# Params size (MB): 548.05
# Estimated Total Size (MB): 787.31
# ----------------------------------------------------------------

# %%
# Modify the final fully connected layer to match the dataset classes
# Write your code here
model.classifier[-1]=nn.Linear(model.classifier[-1].in_features,1)

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
summary(model, input_size=(3, 224, 224))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 224, 224]           1,792
#               ReLU-2         [-1, 64, 224, 224]               0
#             Conv2d-3         [-1, 64, 224, 224]          36,928
#               ReLU-4         [-1, 64, 224, 224]               0
#          MaxPool2d-5         [-1, 64, 112, 112]               0
#             Conv2d-6        [-1, 128, 112, 112]          73,856
#               ReLU-7        [-1, 128, 112, 112]               0
#             Conv2d-8        [-1, 128, 112, 112]         147,584
#               ReLU-9        [-1, 128, 112, 112]               0
#         MaxPool2d-10          [-1, 128, 56, 56]               0
#            Conv2d-11          [-1, 256, 56, 56]         295,168
#              ReLU-12          [-1, 256, 56, 56]               0
#            Conv2d-13          [-1, 256, 56, 56]         590,080
#              ReLU-14          [-1, 256, 56, 56]               0
#            Conv2d-15          [-1, 256, 56, 56]         590,080
#              ReLU-16          [-1, 256, 56, 56]               0
#            Conv2d-17          [-1, 256, 56, 56]         590,080
#              ReLU-18          [-1, 256, 56, 56]               0
#         MaxPool2d-19          [-1, 256, 28, 28]               0
#            Conv2d-20          [-1, 512, 28, 28]       1,180,160
#              ReLU-21          [-1, 512, 28, 28]               0
#            Conv2d-22          [-1, 512, 28, 28]       2,359,808
#              ReLU-23          [-1, 512, 28, 28]               0
#            Conv2d-24          [-1, 512, 28, 28]       2,359,808
#              ReLU-25          [-1, 512, 28, 28]               0
#            Conv2d-26          [-1, 512, 28, 28]       2,359,808
#              ReLU-27          [-1, 512, 28, 28]               0
#         MaxPool2d-28          [-1, 512, 14, 14]               0
#            Conv2d-29          [-1, 512, 14, 14]       2,359,808
#              ReLU-30          [-1, 512, 14, 14]               0
#            Conv2d-31          [-1, 512, 14, 14]       2,359,808
#              ReLU-32          [-1, 512, 14, 14]               0
#            Conv2d-33          [-1, 512, 14, 14]       2,359,808
#              ReLU-34          [-1, 512, 14, 14]               0
#            Conv2d-35          [-1, 512, 14, 14]       2,359,808
#              ReLU-36          [-1, 512, 14, 14]               0
#         MaxPool2d-37            [-1, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [-1, 512, 7, 7]               0
#            Linear-39                 [-1, 4096]     102,764,544
#              ReLU-40                 [-1, 4096]               0
#           Dropout-41                 [-1, 4096]               0
#            Linear-42                 [-1, 4096]      16,781,312
#              ReLU-43                 [-1, 4096]               0
#           Dropout-44                 [-1, 4096]               0
#            Linear-45                    [-1, 1]           4,097
# ================================================================
# Total params: 139,574,337
# Trainable params: 139,574,337
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 238.68
# Params size (MB): 532.43
# Estimated Total Size (MB): 771.69
# ----------------------------------------------------------------

# %%
# Freeze all layers except the final layer
for param in model.features.parameters():
    param.requires_grad = False  # Freeze feature extractor layers

# %%
# Include the Loss function and optimizer
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
## Step 3: Train the Model
def train_model(model, train_loader,test_loader,num_epochs=10):
    train_losses = []
    val_losses = []
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels.unsqueeze(1).float())
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_losses.append(running_loss/len(train_loader))
        model.eval()
        val_loss = 0.0
        with torch.no_grad():
          for images,labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels.unsqueeze(1).float())
            val_loss += loss.item()
        val_losses.append(val_loss/len(test_loader))
        model.train()

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}')

    # Plot training and validation loss
    print("Name: LAKSHMIDHAR N")
    print("Register Number: 212224230138")
    plt.figure(figsize=(8, 6))
    plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss', marker='o')
    plt.plot(range(1, num_epochs + 1), val_losses, label='Validation Loss', marker='s')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()

# %%
pip install onnx onnxscript
# Out:
# Requirement already satisfied: onnx in /usr/local/lib/python3.12/dist-packages (1.20.1)
# Collecting onnxscript
#   Downloading onnxscript-0.6.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from onnx) (2.0.2)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (5.29.6)
# Requirement already satisfied: typing_extensions>=4.7.1 in /usr/local/lib/python3.12/dist-packages (from onnx) (4.15.0)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx) (0.5.4)
# Collecting onnx_ir<2,>=0.1.15 (from onnxscript)
#   Downloading onnx_ir-0.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxscript) (26.0)
# Requirement already satisfied: sympy>=1.13 in /usr/local/lib/python3.12/dist-packages (from onnx_ir<2,>=0.1.15->onnxscript) (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13->onnx_ir<2,>=0.1.15->onnxscript) (1.3.0)
# Downloading onnxscript-0.6.2-py3-none-any.whl (689 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 689.1/689.1 kB 9.6 MB/s eta 0:00:00
# Downloading onnx_ir-0.2.0-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 6.4 MB/s eta 0:00:00
# Installing collected packages: onnx_ir, onnxscript
# Successfully installed onnx_ir-0.2.0 onnxscript-0.6.2

# %%
dummy_input = torch.randn(1, 3, 224, 224).to(device)

torch.onnx.export(
    model,
    dummy_input,
    "vgg19_model.onnx"
)
# Out:
# W0224 06:06:55.968000 1602 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0224 06:06:55.969000 1602 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0, sampling_ratio: 'int' = -1, aligned: 'bool' = False). Treating as an Input.
# W0224 06:06:55.972000 1602 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'input' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# W0224 06:06:55.974000 1602 torch/onnx/_internal/exporter/_schemas.py:455] Missing annotation for parameter 'boxes' from (input, boxes, output_size: 'Sequence[int]', spatial_scale: 'float' = 1.0). Treating as an Input.
# [torch.onnx] Obtain model graph for `VGG([...]` with `torch.export.export(..., strict=False)`...
# [torch.onnx] Obtain model graph for `VGG([...]` with `torch.export.export(..., strict=False)`... ✅
# [torch.onnx] Run decomposition...
# /usr/lib/python3.12/copyreg.py:99: FutureWarning: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
#   return cls.__new__(cls, *args)
# [torch.onnx] Run decomposition... ✅
# [torch.onnx] Translate the graph into ONNX...
# [torch.onnx] Translate the graph into ONNX... ✅
# ONNXProgram(
#     model=
#         <
#             ir_version=10,
#             opset_imports={'': 20},
#             producer_name='pytorch',
#             producer_version='2.10.0+cu128',
#             domain=None,
#             model_version=None,
#         >
#         graph(
#             name=main_graph,
#             inputs=(
#                 %"x"<FLOAT,[1,3,224,224]>
#             ),
#             outputs=(
#                 %"linear_2"<FLOAT,[1,1]>
#             ),
#             initializers=(
#                 %"features.0.weight"<FLOAT,[64,3,3,3]>{TorchTensor(...)},
#                 %"features.0.bias"<FLOAT,[64]>{TorchTensor(...)},
#                 %"features.2.weight"<FLOAT,[64,64,3,3]>{TorchTensor(...)},
#                 %"features.2.bias"<FLOAT,[64]>{TorchTensor(...)},
#                 %"features.5.weight"<FLOAT,[128,64,3,3]>{TorchTensor(...)},
#                 %"features.5.bias"<FLOAT,[128]>{TorchTensor(...)},
#                 %"features.7.weight"<FLOAT,[128,128,3,3]>{TorchTensor(...)},
#                 %"features.7.bias"<FLOAT,[128]>{TorchTensor(...)},
#                 %"features.10.weight"<FLOAT,[256,128,3,3]>{TorchTensor(...)},
#                 %"features.10.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.12.weight"<FLOAT,[256,256,3,3]>{TorchTensor(...)},
#                 %"features.12.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.14.weight"<FLOAT,[256,256,3,3]>{TorchTensor(...)},
#                 %"features.14.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.16.weight"<FLOAT,[256,256,3,3]>{TorchTensor(...)},
#                 %"features.16.bias"<FLOAT,[256]>{TorchTensor(...)},
#                 %"features.19.weight"<FLOAT,[512,256,3,3]>{TorchTensor(...)},
#                 %"features.19.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.21.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.21.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.23.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.23.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.25.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.25.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.28.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.28.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.30.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.30.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.32.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.32.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"features.34.weight"<FLOAT,[512,512,3,3]>{TorchTensor(...)},
#                 %"features.34.bias"<FLOAT,[512]>{TorchTensor(...)},
#                 %"classifier.0.weight"<FLOAT,[4096,25088]>{TorchTensor(...)},
#                 %"classifier.0.bias"<FLOAT,[4096]>{TorchTensor(...)},
#                 %"classifier.3.weight"<FLOAT,[4096,4096]>{TorchTensor(...)},
#                 %"classifier.3.bias"<FLOAT,[4096]>{TorchTensor(...)},
#                 %"classifier.6.weight"<FLOAT,[1,4096]>{TorchTensor(...)},
#                 %"classifier.6.bias"<FLOAT,[1]>{TorchTensor<FLOAT,[1]>(Parameter containing: tensor([-0.0074], device='cuda:0', requires_grad=True), name='classifier.6.bias')},
#                 %"val_8"<INT64,[2]>{Tensor<INT64,[2]>(array([    1, 25088]), name='val_8')}
#             ),
#         ) {
#              0 |  # node_conv2d
#                   %"conv2d"<FLOAT,[1,64,224,224]> ⬅️ ::Conv(%"x", %"features.0.weight"{...}, %"features.0.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              1 |  # node_relu
#                   %"relu"<FLOAT,[1,64,224,224]> ⬅️ ::Relu(%"conv2d")
#              2 |  # node_conv2d_1
#                   %"conv2d_1"<FLOAT,[1,64,224,224]> ⬅️ ::Conv(%"relu", %"features.2.weight"{...}, %"features.2.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              3 |  # node_relu_1
#                   %"relu_1"<FLOAT,[1,64,224,224]> ⬅️ ::Relu(%"conv2d_1")
#              4 |  # node_max_pool2d
#                   %"max_pool2d"<FLOAT,[1,64,112,112]> ⬅️ ::MaxPool(%"relu_1") {storage_order=0, dilations=(1, 1), ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#              5 |  # node_conv2d_2
#                   %"conv2d_2"<FLOAT,[1,128,112,112]> ⬅️ ::Conv(%"max_pool2d", %"features.5.weight"{...}, %"features.5.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              6 |  # node_relu_2
#                   %"relu_2"<FLOAT,[1,128,112,112]> ⬅️ ::Relu(%"conv2d_2")
#              7 |  # node_conv2d_3
#                   %"conv2d_3"<FLOAT,[1,128,112,112]> ⬅️ ::Conv(%"relu_2", %"features.7.weight"{...}, %"features.7.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#              8 |  # node_relu_3
#                   %"relu_3"<FLOAT,[1,128,112,112]> ⬅️ ::Relu(%"conv2d_3")
#              9 |  # node_max_pool2d_1
#                   %"max_pool2d_1"<FLOAT,[1,128,56,56]> ⬅️ ::MaxPool(%"relu_3") {storage_order=0, dilations=(1, 1), ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#             10 |  # node_conv2d_4
#                   %"conv2d_4"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"max_pool2d_1", %"features.10.weight"{...}, %"features.10.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             11 |  # node_relu_4
#                   %"relu_4"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_4")
#             12 |  # node_conv2d_5
#                   %"conv2d_5"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"relu_4", %"features.12.weight"{...}, %"features.12.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             13 |  # node_relu_5
#                   %"relu_5"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_5")
#             14 |  # node_conv2d_6
#                   %"conv2d_6"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"relu_5", %"features.14.weight"{...}, %"features.14.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             15 |  # node_relu_6
#                   %"relu_6"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_6")
#             16 |  # node_conv2d_7
#                   %"conv2d_7"<FLOAT,[1,256,56,56]> ⬅️ ::Conv(%"relu_6", %"features.16.weight"{...}, %"features.16.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             17 |  # node_relu_7
#                   %"relu_7"<FLOAT,[1,256,56,56]> ⬅️ ::Relu(%"conv2d_7")
#             18 |  # node_max_pool2d_2
#                   %"max_pool2d_2"<FLOAT,[1,256,28,28]> ⬅️ ::MaxPool(%"relu_7") {storage_order=0, dilations=(1, 1), ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#             19 |  # node_conv2d_8
#                   %"conv2d_8"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"max_pool2d_2", %"features.19.weight"{...}, %"features.19.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             20 |  # node_relu_8
#                   %"relu_8"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_8")
#             21 |  # node_conv2d_9
#                   %"conv2d_9"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"relu_8", %"features.21.weight"{...}, %"features.21.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             22 |  # node_relu_9
#                   %"relu_9"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_9")
#             23 |  # node_conv2d_10
#                   %"conv2d_10"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"relu_9", %"features.23.weight"{...}, %"features.23.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             24 |  # node_relu_10
#                   %"relu_10"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_10")
#             25 |  # node_conv2d_11
#                   %"conv2d_11"<FLOAT,[1,512,28,28]> ⬅️ ::Conv(%"relu_10", %"features.25.weight"{...}, %"features.25.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             26 |  # node_relu_11
#                   %"relu_11"<FLOAT,[1,512,28,28]> ⬅️ ::Relu(%"conv2d_11")
#             27 |  # node_max_pool2d_3
#                   %"max_pool2d_3"<FLOAT,[1,512,14,14]> ⬅️ ::MaxPool(%"relu_11") {storage_order=0, dilations=(1, 1), ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#             28 |  # node_conv2d_12
#                   %"conv2d_12"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"max_pool2d_3", %"features.28.weight"{...}, %"features.28.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             29 |  # node_relu_12
#                   %"relu_12"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_12")
#             30 |  # node_conv2d_13
#                   %"conv2d_13"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"relu_12", %"features.30.weight"{...}, %"features.30.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             31 |  # node_relu_13
#                   %"relu_13"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_13")
#             32 |  # node_conv2d_14
#                   %"conv2d_14"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"relu_13", %"features.32.weight"{...}, %"features.32.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             33 |  # node_relu_14
#                   %"relu_14"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_14")
#             34 |  # node_conv2d_15
#                   %"conv2d_15"<FLOAT,[1,512,14,14]> ⬅️ ::Conv(%"relu_14", %"features.34.weight"{...}, %"features.34.bias"{...}) {group=1, pads=(1, 1, 1, 1), auto_pad='NOTSET', strides=(1, 1), dilations=(1, 1)}
#             35 |  # node_relu_15
#                   %"relu_15"<FLOAT,[1,512,14,14]> ⬅️ ::Relu(%"conv2d_15")
#             36 |  # node_max_pool2d_4
#                   %"max_pool2d_4"<FLOAT,[1,512,7,7]> ⬅️ ::MaxPool(%"relu_15") {storage_order=0, dilations=(1, 1), ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(2, 2), kernel_shape=(2, 2)}
#             37 |  # node_avg_pool2d
#                   %"avg_pool2d"<FLOAT,[1,512,7,7]> ⬅️ ::AveragePool(%"max_pool2d_4") {count_include_pad=1, ceil_mode=0, pads=(0, 0, 0, 0), auto_pad='NOTSET', strides=(1, 1), kernel_shape=(1, 1)}
#             38 |  # node_view
#                   %"view"<FLOAT,[1,25088]> ⬅️ ::Reshape(%"avg_pool2d", %"val_8"{[1, 25088]}) {allowzero=1}
#             39 |  # node_linear
#                   %"linear"<FLOAT,[1,4096]> ⬅️ ::Gemm(%"view", %"classifier.0.weight"{...}, %"classifier.0.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             40 |  # node_relu_16
#                   %"relu_16"<FLOAT,[1,4096]> ⬅️ ::Relu(%"linear")
#             41 |  # node_linear_1
#                   %"linear_1"<FLOAT,[1,4096]> ⬅️ ::Gemm(%"relu_16", %"classifier.3.weight"{...}, %"classifier.3.bias"{...}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             42 |  # node_relu_17
#                   %"relu_17"<FLOAT,[1,4096]> ⬅️ ::Relu(%"linear_1")
#             43 |  # node_linear_2
#                   %"linear_2"<FLOAT,[1,1]> ⬅️ ::Gemm(%"relu_17", %"classifier.6.weight"{...}, %"classifier.6.bias"{[-0.007445856463164091]}) {beta=1.0, transB=1, alpha=1.0, transA=0}
#             return %"linear_2"<FLOAT,[1,1]>
#         }
#
#
#     ,
#     exported_program=
#         ExportedProgram:
#             class GraphModule(torch.nn.Module):
#                 def forward(self, p_features_0_weight: "f32[64, 3, 3, 3]", p_features_0_bias: "f32[64]", p_features_2_weight: "f32[64, 64, 3, 3]", p_features_2_bias: "f32[64]", p_features_5_weight: "f32[128, 64, 3, 3]", p_features_5_bias: "f32[128]", p_features_7_weight: "f32[128, 128, 3, 3]", p_features_7_bias: "f32[128]", p_features_10_weight: "f32[256, 128, 3, 3]", p_features_10_bias: "f32[256]", p_features_12_weight: "f32[256, 256, 3, 3]", p_features_12_bias: "f32[256]", p_features_14_weight: "f32[256, 256, 3, 3]", p_features_14_bias: "f32[256]", p_features_16_weight: "f32[256, 256, 3, 3]", p_features_16_bias: "f32[256]", p_features_19_weight: "f32[512, 256, 3, 3]", p_features_19_bias: "f32[512]", p_features_21_weight: "f32[512, 512, 3, 3]", p_features_21_bias: "f32[512]", p_features_23_weight: "f32[512, 512, 3, 3]", p_features_23_bias: "f32[512]", p_features_25_weight: "f32[512, 512, 3, 3]", p_features_25_bias: "f32[512]", p_features_28_weight: "f32[512, 512, 3, 3]", p_features_28_bias: "f32[512]", p_features_30_weight: "f32[512, 512, 3, 3]", p_features_30_bias: "f32[512]", p_features_32_weight: "f32[512, 512, 3, 3]", p_features_32_bias: "f32[512]", p_features_34_weight: "f32[512, 512, 3, 3]", p_features_34_bias: "f32[512]", p_classifier_0_weight: "f32[4096, 25088]", p_classifier_0_bias: "f32[4096]", p_classifier_3_weight: "f32[4096, 4096]", p_classifier_3_bias: "f32[4096]", p_classifier_6_weight: "f32[1, 4096]", p_classifier_6_bias: "f32[1]", x: "f32[1, 3, 224, 224]"):
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d: "f32[1, 64, 224, 224]" = torch.ops.aten.conv2d.default(x, p_features_0_weight, p_features_0_bias, [1, 1], [1, 1]);  x = p_features_0_weight = p_features_0_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu: "f32[1, 64, 224, 224]" = torch.ops.aten.relu.default(conv2d);  conv2d = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_1: "f32[1, 64, 224, 224]" = torch.ops.aten.conv2d.default(relu, p_features_2_weight, p_features_2_bias, [1, 1], [1, 1]);  relu = p_features_2_weight = p_features_2_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_1: "f32[1, 64, 224, 224]" = torch.ops.aten.relu.default(conv2d_1);  conv2d_1 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d: "f32[1, 64, 112, 112]" = torch.ops.aten.max_pool2d.default(relu_1, [2, 2], [2, 2]);  relu_1 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_2: "f32[1, 128, 112, 112]" = torch.ops.aten.conv2d.default(max_pool2d, p_features_5_weight, p_features_5_bias, [1, 1], [1, 1]);  max_pool2d = p_features_5_weight = p_features_5_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_2: "f32[1, 128, 112, 112]" = torch.ops.aten.relu.default(conv2d_2);  conv2d_2 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_3: "f32[1, 128, 112, 112]" = torch.ops.aten.conv2d.default(relu_2, p_features_7_weight, p_features_7_bias, [1, 1], [1, 1]);  relu_2 = p_features_7_weight = p_features_7_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_3: "f32[1, 128, 112, 112]" = torch.ops.aten.relu.default(conv2d_3);  conv2d_3 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_1: "f32[1, 128, 56, 56]" = torch.ops.aten.max_pool2d.default(relu_3, [2, 2], [2, 2]);  relu_3 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_4: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(max_pool2d_1, p_features_10_weight, p_features_10_bias, [1, 1], [1, 1]);  max_pool2d_1 = p_features_10_weight = p_features_10_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_4: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_4);  conv2d_4 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_5: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(relu_4, p_features_12_weight, p_features_12_bias, [1, 1], [1, 1]);  relu_4 = p_features_12_weight = p_features_12_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_5: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_5);  conv2d_5 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_6: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(relu_5, p_features_14_weight, p_features_14_bias, [1, 1], [1, 1]);  relu_5 = p_features_14_weight = p_features_14_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_6: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_6);  conv2d_6 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_7: "f32[1, 256, 56, 56]" = torch.ops.aten.conv2d.default(relu_6, p_features_16_weight, p_features_16_bias, [1, 1], [1, 1]);  relu_6 = p_features_16_weight = p_features_16_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_7: "f32[1, 256, 56, 56]" = torch.ops.aten.relu.default(conv2d_7);  conv2d_7 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_2: "f32[1, 256, 28, 28]" = torch.ops.aten.max_pool2d.default(relu_7, [2, 2], [2, 2]);  relu_7 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_8: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(max_pool2d_2, p_features_19_weight, p_features_19_bias, [1, 1], [1, 1]);  max_pool2d_2 = p_features_19_weight = p_features_19_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_8: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_8);  conv2d_8 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_9: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(relu_8, p_features_21_weight, p_features_21_bias, [1, 1], [1, 1]);  relu_8 = p_features_21_weight = p_features_21_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_9: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_9);  conv2d_9 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_10: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(relu_9, p_features_23_weight, p_features_23_bias, [1, 1], [1, 1]);  relu_9 = p_features_23_weight = p_features_23_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_10: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_10);  conv2d_10 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_11: "f32[1, 512, 28, 28]" = torch.ops.aten.conv2d.default(relu_10, p_features_25_weight, p_features_25_bias, [1, 1], [1, 1]);  relu_10 = p_features_25_weight = p_features_25_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_11: "f32[1, 512, 28, 28]" = torch.ops.aten.relu.default(conv2d_11);  conv2d_11 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_3: "f32[1, 512, 14, 14]" = torch.ops.aten.max_pool2d.default(relu_11, [2, 2], [2, 2]);  relu_11 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_12: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(max_pool2d_3, p_features_28_weight, p_features_28_bias, [1, 1], [1, 1]);  max_pool2d_3 = p_features_28_weight = p_features_28_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_12: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_12);  conv2d_12 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_13: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(relu_12, p_features_30_weight, p_features_30_bias, [1, 1], [1, 1]);  relu_12 = p_features_30_weight = p_features_30_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_13: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_13);  conv2d_13 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_14: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(relu_13, p_features_32_weight, p_features_32_bias, [1, 1], [1, 1]);  relu_13 = p_features_32_weight = p_features_32_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_14: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_14);  conv2d_14 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py:553 in forward, code: return self._conv_forward(input, self.weight, self.bias)
#                     conv2d_15: "f32[1, 512, 14, 14]" = torch.ops.aten.conv2d.default(relu_14, p_features_34_weight, p_features_34_bias, [1, 1], [1, 1]);  relu_14 = p_features_34_weight = p_features_34_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_15: "f32[1, 512, 14, 14]" = torch.ops.aten.relu.default(conv2d_15);  conv2d_15 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:224 in forward, code: return F.max_pool2d(
#                     max_pool2d_4: "f32[1, 512, 7, 7]" = torch.ops.aten.max_pool2d.default(relu_15, [2, 2], [2, 2]);  relu_15 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/pooling.py:1510 in forward, code: return F.adaptive_avg_pool2d(input, self.output_size)
#                     avg_pool2d: "f32[1, 512, 7, 7]" = torch.ops.aten.avg_pool2d.default(max_pool2d_4, [1, 1], [1, 1]);  max_pool2d_4 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torchvision/models/vgg.py:68 in forward, code: x = torch.flatten(x, 1)
#                     view: "f32[1, 25088]" = torch.ops.aten.view.default(avg_pool2d, [1, 25088]);  avg_pool2d = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear: "f32[1, 4096]" = torch.ops.aten.linear.default(view, p_classifier_0_weight, p_classifier_0_bias);  view = p_classifier_0_weight = p_classifier_0_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_16: "f32[1, 4096]" = torch.ops.aten.relu.default(linear);  linear = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/dropout.py:73 in forward, code: return F.dropout(input, self.p, self.training, self.inplace)
#                     clone: "f32[1, 4096]" = torch.ops.aten.clone.default(relu_16);  relu_16 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_1: "f32[1, 4096]" = torch.ops.aten.linear.default(clone, p_classifier_3_weight, p_classifier_3_bias);  clone = p_classifier_3_weight = p_classifier_3_bias = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py:143 in forward, code: return F.relu(input, inplace=self.inplace)
#                     relu_17: "f32[1, 4096]" = torch.ops.aten.relu.default(linear_1);  linear_1 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/dropout.py:73 in forward, code: return F.dropout(input, self.p, self.training, self.inplace)
#                     clone_1: "f32[1, 4096]" = torch.ops.aten.clone.default(relu_17);  relu_17 = None
#
#                     # File: /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py:134 in forward, code: return F.linear(input, self.weight, self.bias)
#                     linear_2: "f32[1, 1]" = torch.ops.aten.linear.default(clone_1, p_classifier_6_weight, p_classifier_6_bias);  clone_1 = p_classifier_6_weight = p_classifier_6_bias = None
#                     return (linear_2,)
#
#         Graph signature:
#             # inputs
#             p_features_0_weight: PARAMETER target='features.0.weight'
#             p_features_0_bias: PARAMETER target='features.0.bias'
#             p_features_2_weight: PARAMETER target='features.2.weight'
#             p_features_2_bias: PARAMETER target='features.2.bias'
#             p_features_5_weight: PARAMETER target='features.5.weight'
#             p_features_5_bias: PARAMETER target='features.5.bias'
#             p_features_7_weight: PARAMETER target='features.7.weight'
#             p_features_7_bias: PARAMETER target='features.7.bias'
#             p_features_10_weight: PARAMETER target='features.10.weight'
#             p_features_10_bias: PARAMETER target='features.10.bias'
#             p_features_12_weight: PARAMETER target='features.12.weight'
#             p_features_12_bias: PARAMETER target='features.12.bias'
#             p_features_14_weight: PARAMETER target='features.14.weight'
#             p_features_14_bias: PARAMETER target='features.14.bias'
#             p_features_16_weight: PARAMETER target='features.16.weight'
#             p_features_16_bias: PARAMETER target='features.16.bias'
#             p_features_19_weight: PARAMETER target='features.19.weight'
#             p_features_19_bias: PARAMETER target='features.19.bias'
#             p_features_21_weight: PARAMETER target='features.21.weight'
#             p_features_21_bias: PARAMETER target='features.21.bias'
#             p_features_23_weight: PARAMETER target='features.23.weight'
#             p_features_23_bias: PARAMETER target='features.23.bias'
#             p_features_25_weight: PARAMETER target='features.25.weight'
#             p_features_25_bias: PARAMETER target='features.25.bias'
#             p_features_28_weight: PARAMETER target='features.28.weight'
#             p_features_28_bias: PARAMETER target='features.28.bias'
#             p_features_30_weight: PARAMETER target='features.30.weight'
#             p_features_30_bias: PARAMETER target='features.30.bias'
#             p_features_32_weight: PARAMETER target='features.32.weight'
#             p_features_32_bias: PARAMETER target='features.32.bias'
#             p_features_34_weight: PARAMETER target='features.34.weight'
#             p_features_34_bias: PARAMETER target='features.34.bias'
#             p_classifier_0_weight: PARAMETER target='classifier.0.weight'
#             p_classifier_0_bias: PARAMETER target='classifier.0.bias'
#             p_classifier_3_weight: PARAMETER target='classifier.3.weight'
#             p_classifier_3_bias: PARAMETER target='classifier.3.bias'
#             p_classifier_6_weight: PARAMETER target='classifier.6.weight'
#             p_classifier_6_bias: PARAMETER target='classifier.6.bias'
#             x: USER_INPUT
#
#             # outputs
#             linear_2: USER_OUTPUT
#
#         Range constraints: {}
#
# )

# %%
# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
# Train the model
# Write your code here
train_model(model,train_loader,test_loader)
# Out:
# Epoch [1/10], Train Loss: 0.0675, Validation Loss: 2.0133
# Epoch [2/10], Train Loss: 0.0074, Validation Loss: 1.5367
# Epoch [3/10], Train Loss: 0.0000, Validation Loss: 1.4826
# Epoch [4/10], Train Loss: 0.0000, Validation Loss: 1.4617
# Epoch [5/10], Train Loss: 0.0000, Validation Loss: 1.4535
# Epoch [6/10], Train Loss: 0.0000, Validation Loss: 1.4524
# Epoch [7/10], Train Loss: 0.0000, Validation Loss: 1.4532
# Epoch [8/10], Train Loss: 0.0000, Validation Loss: 1.4541
# Epoch [9/10], Train Loss: 0.0000, Validation Loss: 1.4546
# Epoch [10/10], Train Loss: 0.0000, Validation Loss: 1.4549
# Name: LAKSHMIDHAR N
# Register Number: 212224230138

# %%
## Step 4: Test the Model and Compute Confusion Matrix & Classification Report
def test_model(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            probs = torch.sigmoid(outputs)
            predicted = (probs > 0.5).int().squeeze(1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    accuracy = correct / total
    print(f'Test Accuracy: {accuracy:.4f}')

    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_preds)
    print("Name: NARENDHIRAN P")
    print("Register Number: 212224230177")
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=train_dataset.classes, yticklabels=train_dataset.classes)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # Print classification report
    print("Name: LAKSHMIDHAR N")
    print("Register Number: 212224230138")
    print("Classification Report:")
    print(classification_report(all_labels, all_preds, target_names=train_dataset.classes))

# %%
# Evaluate the model
# write your code here
test_model(model,test_loader)
# Out:
# Test Accuracy: 0.9669
# Name: NARENDHIRAN P
# Register Number: 212224230177
# Name: LAKSHMIDHAR N
# Register Number: 212224230138
# Classification Report:
#               precision    recall  f1-score   support
#
#       defect       0.97      0.91      0.94        33
#    notdefect       0.97      0.99      0.98        88
#
#     accuracy                           0.97       121
#    macro avg       0.97      0.95      0.96       121
# weighted avg       0.97      0.97      0.97       121

# %%
## Step 5: Predict on a Single Image and Display It
def predict_image(model, image_index, dataset):
    model.eval()
    image, label = dataset[image_index]
    with torch.no_grad():
        image_tensor = image.unsqueeze(0).to(device)
        output = model(image_tensor)

        # Apply sigmoid to get probability, threshold at 0.5
        prob = torch.sigmoid(output)
        predicted = (prob > 0.5).int().item()


    class_names = class_names = dataset.classes
    # Display the image
    image_to_display = transforms.ToPILImage()(image)
    plt.figure(figsize=(4, 4))
    plt.imshow(image_to_display)
    plt.title(f'Actual: {class_names[label]}\nPredicted: {class_names[predicted]}')
    plt.axis("off")
    plt.show()

    print(f'Actual: {class_names[label]}, Predicted: {class_names[predicted]}')

# %%
# Example Prediction
predict_image(model, image_index=52, dataset=test_dataset)
# Out:
# Actual: notdefect, Predicted: notdefect

# %%
#Example Prediction
predict_image(model, image_index=25, dataset=test_dataset)
# Out:
# Actual: defect, Predicted: defect

# %%
import matplotlib.pyplot as plt

def show_images(loader):
    images, labels = next(iter(loader))
    fig, axes = plt.subplots(1, 6, figsize=(12,4))

    for i in range(6):
        img = images[i].permute(1,2,0)
        axes[i].imshow(img)
        axes[i].set_title(train_dataset.classes[labels[i]])
        axes[i].axis("off")

    plt.show()

show_images(train_loader)

# %%
pip install visualkeras
# Out:
# Collecting visualkeras
#   Downloading visualkeras-0.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (11.3.0)
# Requirement already satisfied: numpy>=1.18.1 in /usr/local/lib/python3.12/dist-packages (from visualkeras) (2.0.2)
# Collecting aggdraw>=1.3.11 (from visualkeras)
#   Downloading aggdraw-1.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Downloading visualkeras-0.2.0-py3-none-any.whl (29 kB)
# Downloading aggdraw-1.4.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 26.8 MB/s eta 0:00:00
# Installing collected packages: aggdraw, visualkeras
# Successfully installed aggdraw-1.4.1 visualkeras-0.2.0

# %%
import visualkeras
visualkeras.layered_view(model.features)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1457592353.py in <cell line: 0>()
#       1 import visualkeras
# ----> 2 visualkeras.layered_view(model.features)
#
# /usr/local/lib/python3.12/dist-packages/visualkeras/layered.py in layered_view(model, to_file, min_z, min_xy, max_z, max_xy, scale_z, scale_xy, type_ignore, index_ignore, color_map, one_dim_orientation, index_2D, background_fill, draw_volume, draw_reversed, padding, text_callable, text_vspacing, spacing, draw_funnel, shade_step, legend, legend_text_spacing_offset, font, font_color, show_dimension, sizing_mode, dimension_caps, relative_base_size, options, preset)
#     252         color_map = dict()
#     253
# --> 254     for index, layer in enumerate(model.layers):
#     255
#     256         # Ignore layers that the use has opted out to
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1963             if name in modules:
#    1964                 return modules[name]
# -> 1965         raise AttributeError(
#    1966             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1967         )
#
# AttributeError: 'Sequential' object has no attribute 'layers'
